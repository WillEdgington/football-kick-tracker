# %% [markdown]
# # Testing YOLO On Shooting Drills
#
# Testing the chosen YOLO pose model (`yolo11l-pose`) on footage of shooting drills from several different angles.

# %% [markdown]
# ## 0. Setup

# %%
import os

# %pip install ultralytics==8.4.26 -q

if not os.path.exists("football-kick-tracker"):
    # !git clone https://github.com/WillEdgington/football-kick-tracker.git
else:
    # !git -C football-kick-tracker pull

# %pip install -e football-kick-tracker --force-reinstall -q

import sys
sys.path.insert(0, '/content/football-kick-tracker')

import IPython
IPython.display.clear_output()
print("Setup complete. Runtime restarting...")
exit()
# Out:
# Setup complete. Runtime restarting...

# %%
from ultralytics import YOLO
from google.colab import drive
from pathlib import Path

from pose.annotate import annotateVideos
from pose.config import RAWTRAININGVIDEOSDIR, ANNOTATEDPOSEVIDEOSDIR, LOWERCOLOURS, CONFTHRESHOLD
from pose.constants import LOWERKEYPOINTS, LOWERSKELETONPAIRS

drive.mount('/content/drive')
driveRepoDir = Path("/content/drive/MyDrive/football-kick-tracker")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## 1. Define video paths
#
# Get paths for shooting drills from an established directory (prefix "shooting-" is used on file names).

# %%
videoDir: Path = driveRepoDir / RAWTRAININGVIDEOSDIR
videoPaths = sorted(
    p for suf in ("*.mp4", "*.mov")
    for p in videoDir.glob(suf)
    if p.stem.startswith("shooting-")
)

assert len(videoPaths) > 0, f"No shooting videos found in {videoDir}"
print(f"Found {len(videoPaths)} videos:")
for p in videoPaths:
    print(f"  {p.name}")
# Out:
# Found 21 videos:
#   shooting-brentford-training-drill-1-1.mov
#   shooting-brentford-training-drill-1-2.mov
#   shooting-brentford-training-drill-1-3.mov
#   shooting-brentford-training-drill-2-1.mov
#   shooting-brentford-training-drill-2-2.mov
#   shooting-brentford-training-drill-2-3.mov
#   shooting-brentford-training-drill-2-4.mov
#   shooting-brentford-training-drill-2-5.mov
#   shooting-brentford-training-drill-2-6.mov
#   shooting-brentford-training-drill-2-7.mov
#   shooting-brentford-training-drill-3-1.mov
#   shooting-brentford-training-drill-3-2.mov
#   shooting-brentford-training-drill-4-1.mov
#   shooting-brentford-training-drill-4-2.mov
#   shooting-brentford-training-drill-4-3.mov
#   shooting-brentford-training-drill-5-1.mov
#   shooting-brentford-training-drill-5-2.mov
#   shooting-brentford-training-drill-6-1.mov
#   shooting-brentford-training-drill-6-2.mov
#   shooting-brentford-training-drill-6-3.mov
#   shooting-brentford-training-drill-7-1.mov

# %% [markdown]
# ## 2. Load YOLO models
#
# Collect chosen model

# %%
modelName = "yolo11l-pose"
try:
    model = YOLO(f"{modelName}.pt")
    print(f"{modelName} loaded")
except Exception as e:
    print(f"{modelName} not available: {e}")
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo11l-pose.pt to 'yolo11l-pose.pt': 100% ━━━━━━━━━━━━ 50.7MB 36.7MB/s 1.4s1.4s<0.0s
# yolo11l-pose loaded

# %% [markdown]
# Check that models are on GPU

# %%
# !nvidia-smi

print(model.device)
# Out:
# Mon Mar 30 12:07:33 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   49C    P8              9W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+
# cpu

# %% [markdown]
# ## 3. Annotate Shooting Videos

# %%
annotateVideosDir: Path = driveRepoDir / ANNOTATEDPOSEVIDEOSDIR

annotatedVideoPaths = annotateVideos(
    model=model,
    name=modelName,
    sourcePaths=videoPaths,
    outputDir=annotateVideosDir,
    keypointIndexes=LOWERKEYPOINTS,
    skeletonPairs=LOWERSKELETONPAIRS,
    colours=LOWERCOLOURS,
    confThreshold=CONFTHRESHOLD,
    logging=True,
    overwrite=False
)
# Out:
# [yolo11l-pose] Annotating shooting-brentford-training-drill-1-1.mov (1/21)...
# Frame 477/477
# Saved to /content/drive/MyDrive/football-kick-tracker/data/sessions/annotated_videos/yolo11l-pose/shooting-brentford-training-drill-1-1.mp4
# [yolo11l-pose] Annotating shooting-brentford-training-drill-1-2.mov (2/21)...
# Frame 777/777
# Saved to /content/drive/MyDrive/football-kick-tracker/data/sessions/annotated_videos/yolo11l-pose/shooting-brentford-training-drill-1-2.mp4
# [yolo11l-pose] Annotating shooting-brentford-training-drill-1-3.mov (3/21)...
# Frame 2752/2752
# Saved to /content/drive/MyDrive/football-kick-tracker/data/sessions/annotated_videos/yolo11l-pose/shooting-brentford-training-drill-1-3.mp4
# [yolo11l-pose] Annotating shooting-brentford-training-drill-2-1.mov (4/21)...
# Frame 1673/1673
# Saved to /content/drive/MyDrive/football-kick-tracker/data/sessions/annotated_videos/yolo11l-pose/shooting-brentford-training-drill-2-1.mp4
# [yolo11l-pose] Annotating shooting-brentford-training-drill-2-2.mov (5/21)...
# Frame 2832/2832
# Saved to /content/drive/MyDrive/football-kick-tracker/data/sessions/annotated_videos/yolo11l-pose/shooting-brentford-training-drill-2-2.mp4
# [yolo11l-pose] Annotating shooting-brentford-training-drill-2-3.mov (6/21)...
# Frame 2567/2567
# Saved to /content/drive/MyDrive/football-kick-tracker/data/sessions/annotated_videos/yolo11l-pose/shooting-brentford-training-drill-2-3.mp4
# [yolo11l-pose] Annotating shooting-brentford-training-drill-2-4.mov (7/21)...
# Frame 1765/1765
# Saved to /content/drive/MyDrive/football-kick-tracker/data/sessions/annotated_videos/yolo11l-pose/shooting-brentford-training-drill-2-4.mp4
# [yolo11l-pose] Annotating shooting-brentford-training-drill-2-5.mov (8/21)...
# Frame 791/791
# Saved to /content/drive/MyDrive/football-kick-tracker/data/sessions/annotated_videos/yolo11l-pose/shooting-brentford-training-drill-2-5.mp4
# [yolo11l-pose] Annotating shooting-brentford-training-drill-2-6.mov (9/21)...
# Frame 647/647
# Saved to /content/drive/MyDrive/football-kick-tracker/data/sessions/annotated_videos/yolo11l-pose/shooting-brentford-training-drill-2-6.mp4
# [yolo11l-pose] Annotating shooting-brentford-training-drill-2-7.mov (10/21)...
# Frame 2825/2825
# Saved to /content/drive/MyDrive/football-kick-tracker/data/sessions/annotated_videos/yolo11l-pose/shooting-brentford-training-drill-2-7.mp4
# [yolo11l-pose] Annotating shooting-brentford-training-drill-3-1.mov (11/21)...
# Frame 2452/2452
# Saved to /content/drive/MyDrive/football-kick-tracker/data/sessions/annotated_videos/yolo11l-pose/shooting-brentford-training-drill-3-1.mp4
# [yolo11l-pose] Annotating shooting-brentford-training-drill-3-2.mov (12/21)...
# Frame 1577/1577
# Saved to /content/drive/MyDrive/football-kick-tracker/data/sessions/annotated_videos/yolo11l-pose/shooting-brentford-training-drill-3-2.mp4
# [yolo11l-pose] Annotating shooting-brentford-training-drill-4-1.mov (13/21)...
# Frame 1123/1123
# Saved to /content/drive/MyDrive/football-kick-tracker/data/sessions/annotated_videos/yolo11l-pose/shooting-brentford-training-drill-4-1.mp4
# [yolo11l-pose] Annotating shooting-brentford-training-drill-4-2.mov (14/21)...
# Frame 1183/1183
# Saved to /content/drive/MyDrive/football-kick-tracker/data/sessions/annotated_videos/yolo11l-pose/shooting-brentford-training-drill-4-2.mp4
# [yolo11l-pose] Annotating shooting-brentford-training-drill-4-3.mov (15/21)...
# Frame 3208/3208
# Saved to /content/drive/MyDrive/football-kick-tracker/data/sessions/annotated_videos/yolo11l-pose/shooting-brentford-training-drill-4-3.mp4
# [yolo11l-pose] Annotating shooting-brentford-training-drill-5-1.mov (16/21)...
# Frame 1527/1527
# Saved to /content/drive/MyDrive/football-kick-tracker/data/sessions/annotated_videos/yolo11l-pose/shooting-brentford-training-drill-5-1.mp4
# [yolo11l-pose] Annotating shooting-brentford-training-drill-5-2.mov (17/21)...
# Frame 1643/1643
# Saved to /content/drive/MyDrive/football-kick-tracker/data/sessions/annotated_videos/yolo11l-pose/shooting-brentford-training-drill-5-2.mp4
# [yolo11l-pose] Annotating shooting-brentford-training-drill-6-1.mov (18/21)...
# Frame 469/469
# Saved to /content/drive/MyDrive/football-kick-tracker/data/sessions/annotated_videos/yolo11l-pose/shooting-brentford-training-drill-6-1.mp4
# [yolo11l-pose] Annotating shooting-brentford-training-drill-6-2.mov (19/21)...
# Frame 1148/1148
# Saved to /content/drive/MyDrive/football-kick-tracker/data/sessions/annotated_videos/yolo11l-pose/shooting-brentford-training-drill-6-2.mp4
# [yolo11l-pose] Annotating shooting-brentford-training-drill-6-3.mov (20/21)...
# Frame 4654/4654
# Saved to /content/drive/MyDrive/football-kick-tracker/data/sessions/annotated_videos/yolo11l-pose/shooting-brentford-training-drill-6-3.mp4
# [yolo11l-pose] Annotating shooting-brentford-training-drill-7-1.mov (21/21)...
# Frame 1402/1402
# Saved to /content/drive/MyDrive/football-kick-tracker/data/sessions/annotated_videos/yolo11l-pose/shooting-brentford-training-drill-7-1.mp4
#
# [yolo11l-pose] Done - 21 annotated, 0 skipped.

# %% [markdown]
# ## 4. Observations
#
# **Experiment Structure:**
#
# - Used `yolo11l-pose` model (See `YOLO_candidate_comparison.ipynb` notebook for reason why this is the current model of choice)
# - Annotated several high quality videos of one shooting drill session (outside, sunny, ~one coach, one player, one ball in action) from several different camera angles.
# - Did not evaluate keypoint confidence and detection rate like in `YOLO_candidate_comparison.ipynb` due to the single-player setting on the footage (we would be rewarding confident hallucinations if we did).
# - Decided that visual evaluation of annotated clips was the most accurate and time efficient method to see the model's performance (manual labelling will be needed at a later date in the project).
#
# Camera angles observed (*{horizontal to subject}-{height}-{distance}*):
#
# *NOTE: low height is ~hip level, mid and high is drone level*
# - behind-high-mid
# - behind-mid-far
# - behind-mid-mid
# - behind-low-mid
# - behind-low-close
# - side-low-far
#
# **Notes:**
# - Model works best at hip level and at a close to mid range distance (the closer and more direct the angle, the better the model worked).
# - Model failed at far distance (this was similar to what was seen from the rondo clips tested in `YOLO_candidate_comparison.ipynb`).
# - Model also failed mostly at drone footage (at behind-high-mid we also had quite heavy hallucinations due to shadows).
# - Model performed much better at behind-mid-far than it did at behind-mid-mid (this shows that the more the subject's shape is foreshortened, the harder it is for the model).
# - There was the occasional hallucination on the football mannequins (not enough for it to be a big concern).
# - Overall the model was a lot less jittery than I thought it would be. When it worked it worked well, when it failed it failed heavily.
#
# **Decision:**
# - Cements that future experimentation on non-YOLO alternatives and possible fine-tuning is needed to make pose estimation robust for the task at hand.
# - `yolo11l-pose` remains sufficient to progress with for now. However, I do doubt its use in production.
